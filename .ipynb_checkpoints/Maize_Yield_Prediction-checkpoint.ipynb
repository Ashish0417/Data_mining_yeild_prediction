# %% [markdown]
# # Maize Yield Prediction in Central Europe
#
# This notebook implements the methodology from the MDPI paper:
# **"Data Mining and Machine Learning Algorithms for Optimizing Maize Yield Forecasting in Central Europe"**.
#
# It predicts maize yield using various agricultural and climate data scenarios and compares the performance of 4 machine learning algorithms (Bagging, Decision Table proxy, Random Forest, and ANN-MLP).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Models
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# ## 1. Load Dataset
# The dataset contains maize yield and climate variables from 1921 to 2018 in Hungary.

# %%
# Load dataset
df = pd.read_csv('final_maize_climate_dataset.csv')
display(df.head())

# Define Target Output (Y)
# The paper predicts maize yield.
y = df['Maize_avg_yield']

# Define the full feature set as specified in the paper
features = df[['Maize_sown_area', 'Maize_production', 'Tmean', 'PRCP', 'RD', 'FD', 'HD']]

# Map column names for easier reference matching the paper
features.columns = ['AREA', 'PROD', 'Tmean', 'PRCP', 'RD', 'FD', 'HD']
# Out:
#    year     PRCP     RD      Tmean      Tmin       Tmax       Tvar     FD  \
# 0  1921   864.00  143.4  10.535836  5.618246  15.958466  10.340220   83.0
# 1  1922  1372.86  192.0   9.612548  5.244767  14.247288   9.002521  118.6
# 2  1923  1120.68  186.0  11.106795  6.554356  16.023836   9.469479   72.4
# 3  1924  1152.66  156.8   9.811585  5.526995  14.403661   8.876667  158.8
# 4  1925  1374.16  191.2  10.552055  5.774027  15.396986   9.622959   91.0
#
#       HD      GDD  Heat_Stress  Cold_Stress  Maize_sown_area  \
# 0  50.40  2830.26    13.800000        197.6           876974
# 1  50.80  2775.36     7.750000        206.0           989459
# 2  41.20  3026.70     3.333333        130.4           995177
# 3  30.60  3017.74     5.000000        228.4          1003343
# 4  26.75  2819.10     0.000000        181.4          1082099
#
#    Maize_production  Maize_avg_yield  Yield_computed
# 0            805295              920        0.918266
# ...

# %% [markdown]
# ## 2. Define Scenarios
# - **SC1**: AREA + PROD + Tmean + PRCP + RD + FD + HD
# - **SC2**: AREA + PROD
# - **SC3**: Tmean + PRCP + RD + FD + HD
# - **SC4**: AREA + PROD + Tmean + PRCP

# %%
scenarios = {
    'SC1': ['AREA', 'PROD', 'Tmean', 'PRCP', 'RD', 'FD', 'HD'],
    'SC2': ['AREA', 'PROD'],
    'SC3': ['Tmean', 'PRCP', 'RD', 'FD', 'HD'],
    'SC4': ['AREA', 'PROD', 'Tmean', 'PRCP']
}

# %% [markdown]
# ## 3. Evaluation Metrics
# The paper evaluates the models using:
# 1. **r**: Correlation coefficient
# 2. **MAE**: Mean Absolute Error
# 3. **RMSE**: Root Mean Squared Error
# 4. **RAE**: Relative Absolute Error
# 5. **RRSE**: Root Relative Squared Error

# %%
def calculate_metrics(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Correlation Coefficient (r)
    r = np.corrcoef(y_true, y_pred)[0, 1]
    
    # Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    
    # Root Mean Squared Error (RMSE)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    # Mean of true values
    y_mean = np.mean(y_true)
    
    # Relative Absolute Error (RAE) in %
    # RAE = sum(|y_pred - y_true|) / sum(|y_mean - y_true|) * 100
    rae = (np.sum(np.abs(y_pred - y_true)) / np.sum(np.abs(y_mean - y_true))) * 100
    
    # Root Relative Squared Error (RRSE) in %
    # RRSE = sqrt( sum((y_pred - y_true)^2) / sum((y_mean - y_true)^2) ) * 100
    rrse = np.sqrt(np.sum((y_pred - y_true)**2) / np.sum((y_mean - y_true)**2)) * 100
    
    return {'r': r, 'MAE': mae, 'RMSE': rmse, 'RAE': rae, 'RRSE': rrse}

# %% [markdown]
# ## 4. Define Machine Learning Models
# 1. **Bagging (BG)**: Bagging algorithm with 100 iterations on Decision tree.
# 2. **Decision Table (DT)**: Replaced with Decision Tree Regressor (Depth=3) as a proxy for simple rule-based learning, as `sklearn` has no native decision table logic.
# 3. **Random Forest (RF)**: 100 decision trees.
# 4. **ANN-MLP**: Multi-Layer Perceptron (Sigmoid, lr=0.3, momentum=0.2, 500 epochs, consecutive error patience=20).

# %%
def get_models():
    return {
        'Bagging (BG)': BaggingRegressor(estimator=DecisionTreeRegressor(), n_estimators=100, random_state=1),
        'Decision Table (DT Proxy)': DecisionTreeRegressor(max_depth=3, random_state=1),
        'Random Forest (RF)': RandomForestRegressor(n_estimators=100, max_depth=None, random_state=1),
        'ANN-MLP': MLPRegressor(hidden_layer_sizes=(10,), activation='logistic', 
                                learning_rate_init=0.3, momentum=0.2, 
                                max_iter=500, n_iter_no_change=20, random_state=1)
    }

# %% [markdown]
# ## 5. Experiment 1: 80-20 Train-Test Split
# We randomly split data to 80% training and 20% testing.

# %%
results_split = []

for sc_name, sc_features in scenarios.items():
    # Select Scenario Features
    X = features[sc_features]
    
    # Normalization
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Split data
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.20, random_state=1)
    
    models = get_models()
    for model_name, model in models.items():
        # Train model
        model.fit(X_train, y_train)
        
        # Test phase
        y_pred = model.predict(X_test)
        
        metrics = calculate_metrics(y_test, y_pred)
        metrics['Scenario'] = sc_name
        metrics['Model'] = model_name
        metrics['Phase'] = 'Testing (80-20)'
        
        results_split.append(metrics)

df_results_split = pd.DataFrame(results_split)
df_results_split = df_results_split[['Phase', 'Scenario', 'Model', 'r', 'MAE', 'RMSE', 'RAE', 'RRSE']]
display(df_results_split)
# Out:
#               Phase Scenario                      Model         r  \
# 0   Testing (80-20)      SC1               Bagging (BG)  0.980192
# 1   Testing (80-20)      SC1  Decision Table (DT Proxy)  0.963932
# 2   Testing (80-20)      SC1         Random Forest (RF)  0.980885
# 3   Testing (80-20)      SC1                    ANN-MLP -0.372697
# 4   Testing (80-20)      SC2               Bagging (BG)  0.982508
# 5   Testing (80-20)      SC2  Decision Table (DT Proxy)  0.963932
# 6   Testing (80-20)      SC2         Random Forest (RF)  0.982856
# 7   Testing (80-20)      SC2                    ANN-MLP  0.534183
# 8   Testing (80-20)      SC3               Bagging (BG)  0.321170
# 9   Testing (80-20)      SC3  Decision Table (DT Proxy)  0.213892
# 10  Testing (80-20)      SC3         Random Forest (RF)  0.310746
# 11  Testing (80-20)      SC3                    ANN-MLP -0.412599
# 12  Testing (80-20)      SC4               Bagging (BG)  0.979748
# ...

# %% [markdown]
# ## 6. Experiment 2: 10-Fold Cross Validation
# Evaluate model generalization using k-fold cross validation on the whole dataset.

# %%
results_cv = []
kf = KFold(n_splits=10, shuffle=True, random_state=1)

for sc_name, sc_features in scenarios.items():
    # Select Scenario Features
    X = features[sc_features]
    
    # Normalization
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    y_array = np.array(y)
    
    models = get_models()
    for model_name, model in models.items():
        cv_preds = np.zeros_like(y_array)
        
        for train_idx, test_idx in kf.split(X_scaled):
            X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
            y_train = y_array[train_idx]
            
            model.fit(X_train, y_train)
            cv_preds[test_idx] = model.predict(X_test)
            
        # Calculate metrics over the full cross-validated predictions
        metrics = calculate_metrics(y_array, cv_preds)
        metrics['Scenario'] = sc_name
        metrics['Model'] = model_name
        metrics['Phase'] = '10-Fold CV'
        
        results_cv.append(metrics)

df_results_cv = pd.DataFrame(results_cv)
df_results_cv = df_results_cv[['Phase', 'Scenario', 'Model', 'r', 'MAE', 'RMSE', 'RAE', 'RRSE']]
display(df_results_cv)
# Out:
#          Phase Scenario                      Model         r          MAE  \
# 0   10-Fold CV      SC1               Bagging (BG)  0.983274   257.357143
# 1   10-Fold CV      SC1  Decision Table (DT Proxy)  0.967079   371.908163
# 2   10-Fold CV      SC1         Random Forest (RF)  0.982906   262.173469
# 3   10-Fold CV      SC1                    ANN-MLP -0.318364  2346.887755
# 4   10-Fold CV      SC2               Bagging (BG)  0.989446   207.030612
# 5   10-Fold CV      SC2  Decision Table (DT Proxy)  0.966779   373.795918
# 6   10-Fold CV      SC2         Random Forest (RF)  0.989871   202.275510
# 7   10-Fold CV      SC2                    ANN-MLP -0.310422  2340.724490
# 8   10-Fold CV      SC3               Bagging (BG)  0.561367  1398.581633
# 9   10-Fold CV      SC3  Decision Table (DT Proxy)  0.401688  1647.693878
# 10  10-Fold CV      SC3         Random Forest (RF)  0.559754  1408.632653
# 11  10-Fold CV      SC3                    ANN-MLP -0.318333  2343.071429
# ...
